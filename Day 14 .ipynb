# %% [markdown]
# # Day 14

# %% [markdown]
# ![Day%2014.png](attachment:Day%2014.png)

# %%
class Difference:
    def __init__(self, a):
        self.__elements = a
        self.d = []
        self.maximumDifference=0
    
    
    def computeDifference(self):
        d=[]
        for i in range(len(a)-1):
            for j in range(i+1,len(a)-i):
                diff = a[i]-a[j]
                if diff<0: diff*=-1
                d.append(diff)
        self.maximumDifference=max(d)
        

	# Add your code here

# End of Difference class

_ = input()
a = [int(e) for e in input().split(' ')]

d = Difference(a)
d.computeDifference()

print(d.maximumDifference)
