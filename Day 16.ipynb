# %% [markdown]
# # Day 16:
#
# Exceptions to Interger
#
# Link: https://www.hackerrank.com/challenges/30-exceptions-string-to-integer/problem?isFullScreen=true

# %% [markdown]
# ![Day%2016.png](attachment:Day%2016.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys


import sys


S = input().strip()

try:
    S = int(S)
    print(S)
except:
    print("Bad String")
